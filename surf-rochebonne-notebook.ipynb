# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# Links

url = 'https://www.windguru.cz/112'
executable_path = '/Users/marionchaffaut/chromedriver/chromedriver-mac-x64/chromedriver'

# %%
# Initialisation scraping

driver = webdriver.Chrome(executable_path=executable_path)
driver.get(url)
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
# Save scrapped info into a txt file

text_file = open("forecast.txt", "w")
text_file.write(str(soup.find_all('script')))      
text_file.close()

# %%
new_attempt=driver.find_element(By.XPATH, '//*[@id="tabid_0_0_dates"]/td[2]')

# %%
new_attempt.text
# Out:
# 'We\n12.\n22h'

# %%
num_prev = 50
names_fig = ['tabid_0_0_dates','tabid_0_0_WINDSPD','tabid_0_0_GUST','tabid_0_0_HTSGW', 'tabid_0_0_PERPW']
names_dir = ['tabid_0_0_SMER','tabid_0_0_DIRPW']
forecast = {}

for name in names_fig:
    temp_list = []  
    for i in range(1, num_prev + 1):
        try: 
            value = driver.find_element(By.XPATH, f'//*[@id="{name}"]/td[{i}]')
            temp_list.append(value.text)
        except Exception as e:
            temp_list.append('na')
    forecast[name] = temp_list  

for name in names_dir:
    temp_list = []  
    for i in range(1, num_prev + 1):
        try:
            value = driver.find_element(By.XPATH, f'//*[@id="{name}"]/td[{i}]/span')
            temp_list.append(value.get_attribute('title'))
        except Exception as e:
            temp_list.append('na')
    forecast[name] = temp_list 

pd.DataFrame(forecast)
# Out:
#    tabid_0_0_dates tabid_0_0_WINDSPD tabid_0_0_GUST tabid_0_0_HTSGW  \
# 0     We\n12.\n20h                 7             13             0.3
# 1     We\n12.\n22h                 7             12             0.3
# 2     Th\n13.\n03h                 4              7             0.2
# 3     Th\n13.\n05h                 5              7             0.3
# 4     Th\n13.\n07h                 6              9             0.3
# 5     Th\n13.\n09h                 8             14             0.4
# 6     Th\n13.\n11h                11             19             0.5
# 7     Th\n13.\n13h                12             21             0.5
# 8     Th\n13.\n15h                14             24             0.7
# 9     Th\n13.\n17h                14             26             0.8
# 10    Th\n13.\n19h                14             24             0.9
# 11    Th\n13.\n21h                14             25             1.1
# 12    Fr\n14.\n03h                 8             15             0.7
# 13    Fr\n14.\n05h                 8             14             0.7
# 14    Fr\n14.\n07h                 9             15             0.7
# 15    Fr\n14.\n09h                10             18             0.7
# 16    Fr\n14.\n11h                12             21             0.7
# 17    Fr\n14.\n13h                13             25             0.8
# 18    Fr\n14.\n15h                13             23             0.8
# 19    Fr\n14.\n17h                12             21             0.9
# 20    Fr\n14.\n19h                 9             16             0.9
# 21    Fr\n14.\n21h                13             24             1.1
# 22    Sa\n15.\n03h                13             23             1.3
# 23    Sa\n15.\n05h                12             22             1.3
# 24    Sa\n15.\n07h                12             22             1.2
# 25    Sa\n15.\n09h                13             23             1.2
# 26    Sa\n15.\n11h                15             26             1.3
# 27    Sa\n15.\n13h                15             25             1.3
# 28    Sa\n15.\n15h                15             26             1.5
# 29    Sa\n15.\n17h                13             25             1.3
# 30    Sa\n15.\n19h                11             21             1.4
# 31    Su\n16.\n05h                 8             15               1
# 32    Su\n16.\n07h                 7             14             0.9
# 33    Su\n16.\n09h                 7             13             0.8
# 34    Su\n16.\n11h                 6             13             0.7
# 35    Su\n16.\n13h                 6             11             0.6
# 36    Su\n16.\n15h                 6             11             0.5
# 37    Su\n16.\n17h                 6             12             0.5
# 38    Su\n16.\n19h                 4              7             0.4
# 39    Mo\n17.\n05h                 7             13             0.4
# 40    Mo\n17.\n07h                 6             10             0.4
# 41    Mo\n17.\n09h                 5             10             0.4
# 42    Mo\n17.\n11h                 5             11             0.4
# 43    Mo\n17.\n13h                 5              9             0.3
# 44    Mo\n17.\n15h                 4              9             0.3
# 45    Mo\n17.\n17h                 6             11             0.3
# 46    Mo\n17.\n19h                 6              8             0.2
# 47    Tu\n18.\n05h                 5              6
# 48    Tu\n18.\n08h                 5              6             0.2
# 49    Tu\n18.\n11h                 6              8             0.2
#
#    tabid_0_0_PERPW tabid_0_0_SMER tabid_0_0_DIRPW
# 0                4     NNW (327°)       NW (325°)
# 1                3      NW (316°)       NW (322°)
# 2                3      SW (234°)      WNW (286°)
# 3                4       S (182°)      WNW (295°)
# 4                2       S (173°)        S (191°)
# 5                3       S (170°)        S (187°)
# 6                3       S (175°)      SSW (194°)
# 7                3     SSW (192°)      SSW (199°)
# 8                3     SSW (203°)       SW (218°)
# 9                4     SSW (202°)      SSW (208°)
# 10               4     SSW (192°)      SSW (200°)
# 11               4       S (178°)      SSW (197°)
# 12              10      SW (218°)        W (267°)
# 13               3      SW (232°)      WSW (243°)
# 14               4      SW (216°)      WSW (246°)
# 15               4      SW (224°)      WSW (247°)
# 16               4      SW (222°)      WSW (253°)
# 17               9      SW (217°)        W (279°)
# 18               4     WSW (237°)      WSW (258°)
# 19               4     WSW (244°)      WSW (251°)
# 20               4     WSW (257°)        W (259°)
# 21               5      SW (228°)        W (259°)
# 22               5      SW (236°)        W (265°)
# 23               5      SW (233°)        W (267°)
# 24               5      SW (224°)        W (269°)
# 25               5      SW (227°)      WSW (253°)
# 26               5     WSW (237°)      WSW (249°)
# 27               5     WSW (238°)      WSW (249°)
# 28               5     WSW (240°)        W (261°)
# 29               5     WSW (244°)        W (281°)
# 30               5     WSW (247°)      WNW (285°)
# 31               4       S (185°)       SW (236°)
# 32               8     SSW (192°)        W (269°)
# 33              10     SSW (208°)      WNW (289°)
# 34              10       W (261°)      WNW (291°)
# 35              10     NNW (329°)      WNW (288°)
# 36              10       N (352°)      WNW (287°)
# 37              10       N (354°)      WNW (291°)
# 38              10         N (7°)      WNW (292°)
# 39              10     SSW (212°)      WNW (291°)
# 40               5      SW (234°)       SW (233°)
# 41               3     WSW (250°)      SSW (210°)
# 42               3     WSW (256°)      SSW (212°)
# 43               7      NW (321°)        W (262°)
# 44               9       N (355°)      WNW (289°)
# 45               9         N (0°)      WNW (288°)
# 46               9     NNW (340°)      WNW (289°)
# 47                       S (187°)              na
# 48               9      SE (138°)      WNW (288°)
# 49               8     ESE (122°)      WNW (288°)
